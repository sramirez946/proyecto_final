# %% [markdown]
# <a href="https://colab.research.google.com/github/sramirez946/proyecto_final/blob/main/CANASTA_FAMILIAR_(1)_json.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# INTEGRANTES: SANTIAGO RAMÍREZ-JUAN PABLO SALDAÑA- VALERIA FRANCO

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Lista = {"Alimentos":["Cadera", "Camarón tigre", "Costilla", "Lomo", "Tilapia", "Pechuga de pollo", "Sobrebarriga", "Aguacate", "Banano", "Coco", "Fresa", "Guayaba", "Limón", "Lulo", "Mandarina", "Mango", "Manzana roja", "Manzana verde", "Maracuyá", "Melon", "Mora", "Naranja", "Papaya", "Sandía", "Piña", "Pitahaya", "Tomate de árbol", "Uva", "Aceite", "Arroz", "Azúcar", "Café", "Frijol", "Garbanzo", "Harina de maíz", "Harina todo uso", "Leche en polvo", "Maíz", "Manteca", "Panela", "Pasta", "Sal", "Queso cuajada", "Queso campesino", "Platano harton", "Papa criolla", "Papa pastusa", "Yuca llanera", "Ajo", "Apio", "Brocoli", "Arveja", "Calabaza", "Cebolla cabezona", "Cebolla larga", "Cilantro", "Coliflor", "Espinaca", "Habichuela", "Lechuga", "Mazorca", "Pepino", "Pimentón", "Remolacha", "Repollo", "Tomate", "Zanahoria", "Leche", "Huevos", "Lentejas"],
        "Precios_2024": [32000, 34000, 25000, 60000, 12000, 16000, 25000, 6000, 2200, 5800, 8000, 3000, 1700, 4400, 8630, 5000, 9400, 10500, 4000, 3300, 6420, 2800, 1500, 1600, 2700, 4000, 2400, 7000, 9100, 3600, 4000, 36000, 7600, 9200, 3500, 3200, 12400, 1800, 13000, 3750, 5000, 1000, 19000, 19000, 3100, 2600, 1900, 1800, 7500, 2000, 4000, 3600, 2000, 1000, 4000, 10000, 4000, 7000, 2400, 4000, 3400, 2500, 3500, 1600, 1800, 4000, 3400, 26500, 13500, 4100]}

# %%
df_1 = pd.DataFrame(Lista)
df_1
# Out:
#         Alimentos  Precios_2024
# 0          Cadera         32000
# 1   Camarón tigre         34000
# 2        Costilla         25000
# 3            Lomo         60000
# 4         Tilapia         12000
# ..            ...           ...
# 65         Tomate          4000
# 66      Zanahoria          3400
# 67          Leche         26500
# 68         Huevos         13500
# 69       Lentejas          4100
#
# [70 rows x 2 columns]

# %%
Lista_2 = {"Alimentos":["Cadera", "Camarón tigre", "Costilla", "Lomo", "Tilapia", "Pechuga de pollo", "Sobrebarriga", "Aguacate", "Banano", "Coco", "Fresa", "Guayaba", "Limón", "Lulo", "Mandarina", "Mango", "Manzana roja", "Manzana verde", "Maracuyá", "Melon", "Mora", "Naranja", "Papaya", "Sandía", "Piña", "Pitahaya", "Tomate de árbol", "Uva", "Aceite", "Arroz", "Azúcar", "Café", "Frijol", "Garbanzo", "Harina de maíz", "Harina todo uso", "Leche en polvo", "Maíz", "Manteca", "Panela", "Pasta", "Sal", "Queso cuajada", "Queso campesino", "Platano harton", "Papa criolla", "Papa pastusa", "Yuca llanera", "Ajo", "Apio", "Brocoli", "Arveja", "Calabaza", "Cebolla cabezona", "Cebolla larga", "Cilantro", "Coliflor", "Espinaca", "Habichuela", "Lechuga", "Mazorca", "Pepino", "Pimentón", "Remolacha", "Repollo", "Tomate", "Zanahoria", "Leche", "Huevos", "Lentejas"],
           "Precios 2022":[31000, 33000, 16490, 19070, 11900, 12100, 22900, 5900, 1200, 2500, 4692, 1800, 3900, 3969, 3100, 3800, 7900, 6725, 4000, 1900, 4300, 1026, 2500, 1200, 1130, 2500, 2800, 5800, 10340, 2815, 2855, 21700, 6733, 9100, 3936, 3700, 28725, 2333, 12000, 4100, 6500, 1500, 11750, 14458, 2014, 2321, 2850, 2000, 7200, 1100, 2000, 3700, 2500, 2300, 3000, 2500, 2870, 6500, 3849, 3539, 2200, 1800, 2350, 9005, 507, 2373, 678, 20000, 5592, 5900]}

# %%
df_2 = pd.DataFrame(Lista_2)
df_2
# Out:
#         Alimentos  Precios 2022
# 0          Cadera         31000
# 1   Camarón tigre         33000
# 2        Costilla         16490
# 3            Lomo         19070
# 4         Tilapia         11900
# ..            ...           ...
# 65         Tomate          2373
# 66      Zanahoria           678
# 67          Leche         20000
# 68         Huevos          5592
# 69       Lentejas          5900
#
# [70 rows x 2 columns]

# %%
alimentos = df_1.Alimentos.values

# %%
precios_2024 = df_1["Precios_2024"].values
print(precios_2024)
# Out:
# [32000 34000 25000 60000 12000 16000 25000  6000  2200  5800  8000  3000
#   1700  4400  8630  5000  9400 10500  4000  3300  6420  2800  1500  1600
#   2700  4000  2400  7000  9100  3600  4000 36000  7600  9200  3500  3200
#  12400  1800 13000  3750  5000  1000 19000 19000  3100  2600  1900  1800
#   7500  2000  4000  3600  2000  1000  4000 10000  4000  7000  2400  4000
#   3400  2500  3500  1600  1800  4000  3400 26500 13500  4100]

# %%
#Son los valores del 2022
implemento = df_2["Precios 2022"].values
print(implemento)
# Out:
# [31000 33000 16490 19070 11900 12100 22900  5900  1200  2500  4692  1800
#   3900  3969  3100  3800  7900  6725  4000  1900  4300  1026  2500  1200
#   1130  2500  2800  5800 10340  2815  2855 21700  6733  9100  3936  3700
#  28725  2333 12000  4100  6500  1500 11750 14458  2014  2321  2850  2000
#   7200  1100  2000  3700  2500  2300  3000  2500  2870  6500  3849  3539
#   2200  1800  2350  9005   507  2373   678 20000  5592  5900]

# %%
c = df_1.iloc[0:25]
print(c)
# Out:
#            Alimentos  Precios_2024
# 0             Cadera         32000
# 1      Camarón tigre         34000
# 2           Costilla         25000
# 3               Lomo         60000
# 4            Tilapia         12000
# 5   Pechuga de pollo         16000
# 6       Sobrebarriga         25000
# 7           Aguacate          6000
# 8             Banano          2200
# 9               Coco          5800
# 10             Fresa          8000
# 11           Guayaba          3000
# 12             Limón          1700
# 13              Lulo          4400
# 14         Mandarina          8630
# 15             Mango          5000
# 16      Manzana roja          9400
# 17     Manzana verde         10500
# 18          Maracuyá          4000
# 19             Melon          3300
# 20              Mora          6420
# 21           Naranja          2800
# 22            Papaya          1500
# 23            Sandía          1600
# 24              Piña          2700

# %%
plt.figure(figsize=[14,10])
plt.plot(alimentos,precios_2024, marker="o", label="Precios 2024")
plt.xticks(rotation=90)
plt.legend(loc="upper left")
plt.show()

# %%
plt.figure(figsize=[14,10])
plt.plot(alimentos,implemento, marker="o", label="Implemento 2022-2024")
plt.xticks(rotation=90)
plt.legend(loc="upper left")
plt.show()

# %%
aumento_total = precios_2024.sum()
gasto_total = precios_2024.sum()
total = aumento_total - gasto_total
print(total)
balance_mensual = precios_2024 - implemento
print(balance_mensual)
# Out:
# 0
# [  1000   1000   8510  40930    100   3900   2100    100   1000   3300
#    3308   1200  -2200    431   5530   1200   1500   3775      0   1400
#    2120   1774  -1000    400   1570   1500   -400   1200  -1240    785
#    1145  14300    867    100   -436   -500 -16325   -533   1000   -350
#   -1500   -500   7250   4542   1086    279   -950   -200    300    900
#    2000   -100   -500  -1300   1000   7500   1130    500  -1449    461
#    1200    700   1150  -7405   1293   1627   2722   6500   7908  -1800]

# %%
Total_1 = precios_2024.sum()
Total_2 = implemento.sum()
print("La suma total de los alimentos en el 2024 es: ")
print(Total_1)
print("La suma total de los alimentos en el 2022 es: ")
print(Total_2)
# Out:
# La suma total de los alimentos en el 2024 es:
# 580700
# La suma total de los alimentos en el 2022 es:
# 462295

# %%
#salario Marzo 2024 en base a una familia de 3
print("Ingrese su salario: ")
salario = float(input())
print("Ingrese su gasto mensual en alimentos: ")
gasto = float(input())
porcentaje = salario % gasto / 100
print("El porcentaje del gasto es de: ", porcentaje)
# Out:
# Ingrese su salario:
# 1300000
# Ingrese su gasto mensual en alimentos:
# 500000
# El porcentaje del gasto es de:  3000.0

# %%
#salario Marzo 2022 en base a una familia de 3
print("Ingrese su salario: ")
salario_2 = float(input())
print("Ingrese su gasto mensual en alimentos: ")
gasto_2 = float(input())
porcentaje = salario % gasto / 100
print("El porcentaje disponible es de: ", porcentaje, "%")
# Out:
# Ingrese su salario:
# 1000000
# Ingrese su gasto mensual en alimentos:
# 500000
# El porcentaje disponible es de:  3000.0 %

# %%
#salario Marzo 2024 en base a una familia de 3 con ganancias superiores al salario minimo
print("Ingrese su salario: ")
salario_3 = float(input())
print("Ingrese su gasto mensual en alimentos: ")
gasto_3 = float(input())
porcentaje = salario % gasto / 100
print("El porcentaje del gasto es de: ", porcentaje, "%")
# Out:
# Ingrese su salario:
# 3000000
# Ingrese su gasto mensual en alimentos:
# 500000
# El porcentaje del gasto es de:  3000.0 %

# %%
#salario Marzo 2022 en base a una familia de 3 con ganacias superiores al salario minimo
print("Ingrese su salario: ")
salario = float(input())
print("Ingrese su gasto mensual en alimentos: ")
gasto = float(input())
porcentaje = salario % gasto / 100
print("El porcentaje disponible es de: ", porcentaje, "%")
# Out:
# Ingrese su salario:
# 3000000
# Ingrese su gasto mensual en alimentos:
# 500000
# El porcentaje disponible es de:  0.0 %
